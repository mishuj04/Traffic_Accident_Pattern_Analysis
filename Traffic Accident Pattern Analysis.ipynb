# %% [markdown]
# # Traffic Accident Pattern Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Data Import

# %%
df= pd.read_csv("accident_prediction_india.csv")

# %%
df.head()
# Out:
#           State Name City Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir   Unknown  2021      May      Monday        1:46
# 1      Uttar Pradesh   Lucknow  2018  January   Wednesday       21:30
# 2       Chhattisgarh   Unknown  2023      May   Wednesday        5:37
# 3      Uttar Pradesh   Lucknow  2020     June    Saturday        0:31
# 4             Sikkim   Unknown  2021   August    Thursday       11:21
#
#   Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0           Serious                            5                 Cycle
# 1             Minor                            5                 Truck
# 2             Minor                            5            Pedestrian
# 3             Minor                            3                   Bus
# 4             Minor                            5                 Cycle
#
#    Number of Casualties  ...         Road Type      Road Condition  \
# ...

# %%
df_copy=df.copy()

# %%
df_copy=df_copy.drop("City Name", axis=1)

# %%
df_copy.head()
# Out:
#           State Name  Year    Month Day of Week Time of Day Accident Severity  \
# 0  Jammu and Kashmir  2021      May      Monday        1:46           Serious
# 1      Uttar Pradesh  2018  January   Wednesday       21:30             Minor
# 2       Chhattisgarh  2023      May   Wednesday        5:37             Minor
# 3      Uttar Pradesh  2020     June    Saturday        0:31             Minor
# 4             Sikkim  2021   August    Thursday       11:21             Minor
#
#    Number of Vehicles Involved Vehicle Type Involved  Number of Casualties  \
# 0                            5                 Cycle                     0
# 1                            5                 Truck                     5
# 2                            5            Pedestrian                     6
# 3                            3                   Bus                    10
# 4                            5                 Cycle                     7
#
# ...

# %%
df_copy["Accident Severity"].unique()
# Out:
# array(['Serious', 'Minor', 'Fatal'], dtype=object)

# %%
df_copy["Accident Severity"]=df_copy["Accident Severity"].map({"Serious":2, "Minor":3, "Fatal":1})

# %%
df_copy.head()
# Out:
#           State Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir  2021      May      Monday        1:46
# 1      Uttar Pradesh  2018  January   Wednesday       21:30
# 2       Chhattisgarh  2023      May   Wednesday        5:37
# 3      Uttar Pradesh  2020     June    Saturday        0:31
# 4             Sikkim  2021   August    Thursday       11:21
#
#    Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0                  2                            5                 Cycle
# 1                  3                            5                 Truck
# 2                  3                            5            Pedestrian
# 3                  3                            3                   Bus
# 4                  3                            5                 Cycle
#
#    Number of Casualties  Number of Fatalities  ...         Road Type  \
# 0                     0                     4  ...  National Highway
# ...

# %%
df1=df_copy.copy()

# %%
df1.head()
# Out:
#           State Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir  2021      May      Monday        1:46
# 1      Uttar Pradesh  2018  January   Wednesday       21:30
# 2       Chhattisgarh  2023      May   Wednesday        5:37
# 3      Uttar Pradesh  2020     June    Saturday        0:31
# 4             Sikkim  2021   August    Thursday       11:21
#
#    Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0                  2                            5                 Cycle
# 1                  3                            5                 Truck
# 2                  3                            5            Pedestrian
# 3                  3                            3                   Bus
# 4                  3                            5                 Cycle
#
#    Number of Casualties  Number of Fatalities  ...         Road Type  \
# 0                     0                     4  ...  National Highway
# ...

# %%
df1["Traffic Control Presence"].unique()
# Out:
# array(['Signs', 'Signals', 'Police Checkpost', nan], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State Name                   3000 non-null   object
#  1   Year                         3000 non-null   int64
#  2   Month                        3000 non-null   object
#  3   Day of Week                  3000 non-null   object
#  4   Time of Day                  3000 non-null   object
#  5   Accident Severity            3000 non-null   int64
#  6   Number of Vehicles Involved  3000 non-null   int64
#  7   Vehicle Type Involved        3000 non-null   object
#  8   Number of Casualties         3000 non-null   int64
#  9   Number of Fatalities         3000 non-null   int64
#  10  Weather Conditions           3000 non-null   object
#  11  Road Type                    3000 non-null   object
#  12  Road Condition               3000 non-null   object
# ...

# %% [markdown]
# ## Handling Missing Values

# %%
df1.isnull().sum()
# Out:
# State Name                       0
# Year                             0
# Month                            0
# Day of Week                      0
# Time of Day                      0
# Accident Severity                0
# Number of Vehicles Involved      0
# Vehicle Type Involved            0
# Number of Casualties             0
# Number of Fatalities             0
# Weather Conditions               0
# Road Type                        0
# Road Condition                   0
# Lighting Conditions              0
# Traffic Control Presence       716
# Speed Limit (km/h)               0
# Driver Age                       0
# Driver Gender                    0
# Driver License Status          975
# Alcohol Involvement              0
# Accident Location Details        0
# dtype: int64

# %%
df1["Driver License Status"].unique()
# Out:
# array([nan, 'Valid', 'Expired'], dtype=object)

# %%
df1["Traffic Control Presence"].unique()
# Out:
# array(['Signs', 'Signals', 'Police Checkpost', nan], dtype=object)

# %%
df1["Driver License Status"].fillna(df1["Driver License Status"].mode()[0], inplace= True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9148\2553939312.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Driver License Status"].fillna(df1["Driver License Status"].mode()[0], inplace= True)

# %%
df1["Traffic Control Presence"].fillna(df1["Traffic Control Presence"].mode()[0], inplace= True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9148\1044438379.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Traffic Control Presence"].fillna(df1["Traffic Control Presence"].mode()[0], inplace= True)

# %%
df1.isnull().sum()
# Out:
# State Name                     0
# Year                           0
# Month                          0
# Day of Week                    0
# Time of Day                    0
# Accident Severity              0
# Number of Vehicles Involved    0
# Vehicle Type Involved          0
# Number of Casualties           0
# Number of Fatalities           0
# Weather Conditions             0
# Road Type                      0
# Road Condition                 0
# Lighting Conditions            0
# Traffic Control Presence       0
# Speed Limit (km/h)             0
# Driver Age                     0
# Driver Gender                  0
# Driver License Status          0
# Alcohol Involvement            0
# Accident Location Details      0
# dtype: int64

# %%
df1.head()
# Out:
#           State Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir  2021      May      Monday        1:46
# 1      Uttar Pradesh  2018  January   Wednesday       21:30
# 2       Chhattisgarh  2023      May   Wednesday        5:37
# 3      Uttar Pradesh  2020     June    Saturday        0:31
# 4             Sikkim  2021   August    Thursday       11:21
#
#    Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0                  2                            5                 Cycle
# 1                  3                            5                 Truck
# 2                  3                            5            Pedestrian
# 3                  3                            3                   Bus
# 4                  3                            5                 Cycle
#
#    Number of Casualties  Number of Fatalities  ...         Road Type  \
# 0                     0                     4  ...  National Highway
# ...

# %%
df1["Month"]=df1["Month"].map({"January":1, "February":2, "March":3, "April":4, "May":5, "June":6, "July":7, "August":8, "September":9, "October":10, "November":11, "December":12})

# %%
df1.head()
# Out:
#           State Name  Year  Month Day of Week Time of Day  Accident Severity  \
# 0  Jammu and Kashmir  2021      5      Monday        1:46                  2
# 1      Uttar Pradesh  2018      1   Wednesday       21:30                  3
# 2       Chhattisgarh  2023      5   Wednesday        5:37                  3
# 3      Uttar Pradesh  2020      6    Saturday        0:31                  3
# 4             Sikkim  2021      8    Thursday       11:21                  3
#
#    Number of Vehicles Involved Vehicle Type Involved  Number of Casualties  \
# 0                            5                 Cycle                     0
# 1                            5                 Truck                     5
# 2                            5            Pedestrian                     6
# 3                            3                   Bus                    10
# 4                            5                 Cycle                     7
#
# ...

# %%
df2=df1.copy()

# %%
df2.head()
# Out:
#           State Name  Year  Month Day of Week Time of Day  Accident Severity  \
# 0  Jammu and Kashmir  2021      5      Monday        1:46                  2
# 1      Uttar Pradesh  2018      1   Wednesday       21:30                  3
# 2       Chhattisgarh  2023      5   Wednesday        5:37                  3
# 3      Uttar Pradesh  2020      6    Saturday        0:31                  3
# 4             Sikkim  2021      8    Thursday       11:21                  3
#
#    Number of Vehicles Involved Vehicle Type Involved  Number of Casualties  \
# 0                            5                 Cycle                     0
# 1                            5                 Truck                     5
# 2                            5            Pedestrian                     6
# 3                            3                   Bus                    10
# 4                            5                 Cycle                     7
#
# ...

# %%
df2["Driver License Status"].unique()
# Out:
# array(['Valid', 'Expired'], dtype=object)

# %%
df2["Driver License Status"]=df2["Driver License Status"].map({"Valid":1, "Expired":0})

# %%
df2.head()
# Out:
#           State Name  Year  Month Day of Week Time of Day  Accident Severity  \
# 0  Jammu and Kashmir  2021      5      Monday        1:46                  2
# 1      Uttar Pradesh  2018      1   Wednesday       21:30                  3
# 2       Chhattisgarh  2023      5   Wednesday        5:37                  3
# 3      Uttar Pradesh  2020      6    Saturday        0:31                  3
# 4             Sikkim  2021      8    Thursday       11:21                  3
#
#    Number of Vehicles Involved Vehicle Type Involved  Number of Casualties  \
# 0                            5                 Cycle                     0
# 1                            5                 Truck                     5
# 2                            5            Pedestrian                     6
# 3                            3                   Bus                    10
# 4                            5                 Cycle                     7
#
# ...

# %%
df2["Alcohol Involvement"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df2["Alcohol Involvement"]=df2["Alcohol Involvement"].map({"Yes":1, "No":0})

# %%
df2.head()
# Out:
#           State Name  Year  Month Day of Week Time of Day  Accident Severity  \
# 0  Jammu and Kashmir  2021      5      Monday        1:46                  2
# 1      Uttar Pradesh  2018      1   Wednesday       21:30                  3
# 2       Chhattisgarh  2023      5   Wednesday        5:37                  3
# 3      Uttar Pradesh  2020      6    Saturday        0:31                  3
# 4             Sikkim  2021      8    Thursday       11:21                  3
#
#    Number of Vehicles Involved Vehicle Type Involved  Number of Casualties  \
# 0                            5                 Cycle                     0
# 1                            5                 Truck                     5
# 2                            5            Pedestrian                     6
# 3                            3                   Bus                    10
# 4                            5                 Cycle                     7
#
# ...

# %%
df2["Hour"] = pd.to_datetime(df2["Time of Day"], format="%H:%M").dt.hour
df2["Minute"] = pd.to_datetime(df2["Time of Day"], format="%H:%M").dt.minute

# %%
df2.head()
# Out:
#           State Name  Year  Month Day of Week Time of Day  Accident Severity  \
# 0  Jammu and Kashmir  2021      5      Monday        1:46                  2
# 1      Uttar Pradesh  2018      1   Wednesday       21:30                  3
# 2       Chhattisgarh  2023      5   Wednesday        5:37                  3
# 3      Uttar Pradesh  2020      6    Saturday        0:31                  3
# 4             Sikkim  2021      8    Thursday       11:21                  3
#
#    Number of Vehicles Involved Vehicle Type Involved  Number of Casualties  \
# 0                            5                 Cycle                     0
# 1                            5                 Truck                     5
# 2                            5            Pedestrian                     6
# 3                            3                   Bus                    10
# 4                            5                 Cycle                     7
#
# ...

# %%
def get_time_period(hour):
    if 5 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 21:
        return "Evening"
    else:
        return "Night"

df2["Time Period"] = df2["Hour"].apply(get_time_period)

# %%
df2.head()
# Out:
#           State Name  Year  Month Day of Week Time of Day  Accident Severity  \
# 0  Jammu and Kashmir  2021      5      Monday        1:46                  2
# 1      Uttar Pradesh  2018      1   Wednesday       21:30                  3
# 2       Chhattisgarh  2023      5   Wednesday        5:37                  3
# 3      Uttar Pradesh  2020      6    Saturday        0:31                  3
# 4             Sikkim  2021      8    Thursday       11:21                  3
#
#    Number of Vehicles Involved Vehicle Type Involved  Number of Casualties  \
# 0                            5                 Cycle                     0
# 1                            5                 Truck                     5
# 2                            5            Pedestrian                     6
# 3                            3                   Bus                    10
# 4                            5                 Cycle                     7
#
# ...

# %%
df2["Time Period"].unique()
# Out:
# array(['Night', 'Morning', 'Evening', 'Afternoon'], dtype=object)

# %%
df2.columns
# Out:
# Index(['State Name', 'Year', 'Month', 'Day of Week', 'Time of Day',
#        'Accident Severity', 'Number of Vehicles Involved',
#        'Vehicle Type Involved', 'Number of Casualties', 'Number of Fatalities',
#        'Weather Conditions', 'Road Type', 'Road Condition',
#        'Lighting Conditions', 'Traffic Control Presence', 'Speed Limit (km/h)',
#        'Driver Age', 'Driver Gender', 'Driver License Status',
#        'Alcohol Involvement', 'Accident Location Details', 'Hour', 'Minute',
#        'Time Period'],
#       dtype='object')

# %%
df2["Weather Conditions"].unique()
# Out:
# array(['Hazy', 'Foggy', 'Rainy', 'Stormy', 'Clear'], dtype=object)

# %%
df2["Road Type"].unique()
# Out:
# array(['National Highway', 'Urban Road', 'State Highway', 'Village Road'],
#       dtype=object)

# %%
df2["Road Condition"].unique()
# Out:
# array(['Wet', 'Dry', 'Under Construction', 'Damaged'], dtype=object)

# %%
df2["Lighting Conditions"].unique()
# Out:
# array(['Dark', 'Dusk', 'Dawn', 'Daylight'], dtype=object)

# %% [markdown]
# # Yearwise Number of Fatalities

# %%
df7=df2.groupby('Year')['Number of Fatalities'].sum().reset_index()
df7.columns=['Year','Number']
df7.sort_values(by='Number', ascending=False)
# Out:
#    Year  Number
# 3  2021    1334
# 2  2020    1326
# 4  2022    1245
# 5  2023    1170
# 1  2019    1146
# 0  2018    1145

# %% [markdown]
# # Monthwise Number of Fatalities

# %%
df3 = df2.groupby('Month')['Number of Fatalities'].sum().reset_index()
df3.columns = ['Month', 'Number']

# %%
df3
# Out:
#     Month  Number
# 0       1     659
# 1       2     584
# 2       3     670
# 3       4     580
# 4       5     594
# 5       6     645
# 6       7     511
# 7       8     627
# 8       9     592
# 9      10     672
# 10     11     598
# 11     12     634

# %% [markdown]
# # Number of Fatalities based Vehicle Type

# %%
df4= df2.groupby('Vehicle Type Involved')['Number of Fatalities'].sum().reset_index()
df4.columns=['Vehicle Type','Number']

# %%
df4
# Out:
#     Vehicle Type  Number
# 0  Auto-Rickshaw    1107
# 1            Bus    1080
# 2            Car     936
# 3          Cycle    1083
# 4     Pedestrian    1040
# 5          Truck    1060
# 6    Two-Wheeler    1060

# %% [markdown]
# # Number of Fatalities based on Time Period

# %%
df5= df2.groupby('Time Period')['Number of Fatalities'].sum().reset_index()
df5.columns=['Time Period','Number']

# %%
df5
# Out:
#   Time Period  Number
# 0   Afternoon    1414
# 1     Evening    1214
# 2     Morning    2151
# 3       Night    2587

# %% [markdown]
# # Statewise Number of Casualities

# %%
df6= df2.groupby('State Name')['Number of Casualties'].sum().reset_index()
df6.columns=['States', 'Number']

# %%
df6.sort_values(by= 'Number', ascending=False)
# Out:
#                States  Number
# 7                 Goa     585
# 6               Delhi     566
# 25             Sikkim     548
# 30        Uttarakhand     540
# 22         Puducherry     540
# 8             Gujarat     525
# 14             Kerala     520
# 31        West Bengal     503
# 24          Rajasthan     501
# 11  Jammu and Kashmir     499
# 20           Nagaland     496
# 12          Jharkhand     493
# 9             Haryana     493
# 26         Tamil Nadu     493
# 13          Karnataka     490
# 18          Meghalaya     488
# 29      Uttar Pradesh     479
# 17            Manipur     472
# 16        Maharashtra     468
# 15     Madhya Pradesh     461
# 19            Mizoram     460
# 2               Assam     449
# 3               Bihar     445
# 21             Odisha     441
# 5        Chhattisgarh     441
# 27          Telangana     432
# 10   Himachal Pradesh     429
# 23             Punjab     412
# 28            Tripura     398
# 0      Andhra Pradesh     384
# ...

# %% [markdown]
# # Number of Fatalities base on Age Group

# %%
bins = [0, 18, 30, 45, 60, 75, 100]
labels = ['0-17', '18-29', '30-44', '45-59', '60-74', '75+']
df2['Age Group'] = pd.cut(df2['Driver Age'], bins=bins, labels=labels, right=True)
df8 = df2.groupby('Age Group', observed=True)['Number of Fatalities'].sum().reset_index()
df8.columns=['Age Group', 'Number']
df8.sort_values(by='Number', ascending= False)
# Out:
#   Age Group  Number
# 3     45-59    2189
# 2     30-44    1980
# 1     18-29    1663
# 4     60-74    1366
# 0      0-17     168

# %% [markdown]
# # Number of Fatalities base on Gender

# %%
df9= df2.groupby('Driver Gender')['Number of Fatalities'].sum().reset_index()
df9.columns= ['Driver Gender', 'Number']
df9
# Out:
#   Driver Gender  Number
# 0        Female    3873
# 1          Male    3493

# %% [markdown]
# # Gender v/s Alcohol Involvement

# %%
df10= df2.groupby('Driver Gender')['Alcohol Involvement'].sum().reset_index()
df10.columns= ['Driver Gender', 'Alcohol Involvement']
df10
# Out:
#   Driver Gender  Alcohol Involvement
# 0        Female                  783
# 1          Male                  737

# %% [markdown]
# # Number of Fatalities based on Driver License Status: 0--> Expired, 1--> Valid

# %%
df11= df2.groupby('Driver License Status')['Number of Fatalities'].sum().reset_index()
df11.columns= ['Driver License Status', 'Number']
df11
# Out:
#    Driver License Status  Number
# 0                      0    2300
# 1                      1    5066

# %% [markdown]
# # Number of Fatalities based on Road Type

# %%
df12= df2.groupby('Road Type')['Number of Fatalities'].sum().reset_index()
df12.columns= ['Road Type', 'Number']
df12.sort_values(by= 'Number', ascending= False)
# Out:
#           Road Type  Number
# 1     State Highway    1891
# 3      Village Road    1889
# 0  National Highway    1849
# 2        Urban Road    1737

# %% [markdown]
# # Daywise Accident Severity

# %%
df13= df2.groupby('Day of Week')['Accident Severity'].sum().reset_index()
df13.columns= ['Day of Week', 'Accident Severity']
df13.sort_values(by= 'Accident Severity', ascending= False)
# Out:
#   Day of Week  Accident Severity
# 6   Wednesday                915
# 0      Friday                887
# 4    Thursday                886
# 3      Sunday                862
# 1      Monday                849
# 2    Saturday                841
# 5     Tuesday                809

# %% [markdown]
# # Number of Fatalities based on Location

# %%
df14= df2.groupby('Accident Location Details')['Number of Fatalities'].sum().reset_index()
df14.columns= ['Location', 'Number']
df14.sort_values(by= 'Number', ascending= False)
# Out:
#         Location  Number
# 2   Intersection    1995
# 0         Bridge    1862
# 3  Straight Road    1773
# 1          Curve    1736

# %% [markdown]
# # Monthwise Fatalities Trend

# %%
sns.set_style('white')
plt.figure(figsize=(7,5))
plt.plot(df3['Month'], df3['Number'], marker='o', color= 'red')
plt.title('Monthwise Fatalities Trend', fontsize=16, fontweight='bold')
plt.xlabel('Month', fontsize=12, fontweight='bold')
plt.ylabel('Number of Fatalities', fontsize=12, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
df3.sort_values(by='Number', ascending= False)
# Out:
#     Month  Number
# 9      10     672
# 2       3     670
# 0       1     659
# 5       6     645
# 11     12     634
# 7       8     627
# 10     11     598
# 4       5     594
# 8       9     592
# 1       2     584
# 3       4     580
# 6       7     511

# %% [markdown]
# # Number of Fatalities based on Vehicle Type

# %%
sns.set_style('white')
plt.figure(figsize=(7,5))
plt.bar(df4['Vehicle Type'],df4['Number'], color='blue')
plt.title('Number of Fatalities per Vehicle Type', fontsize=16, fontweight='bold')
plt.xlabel('Vehicle Type', fontsize=12, fontweight= 'bold')
plt.ylabel('Number of Fatalities', fontsize=16, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
df4.sort_values(by='Number', ascending=False)
# Out:
#     Vehicle Type  Number
# 0  Auto-Rickshaw    1107
# 3          Cycle    1083
# 1            Bus    1080
# 5          Truck    1060
# 6    Two-Wheeler    1060
# 4     Pedestrian    1040
# 2            Car     936

# %% [markdown]
# # Number of Fatalities v/s Time Period

# %%
sns.set_style('white')
plt.figure(figsize=(7,5))
plt.bar(df5['Time Period'], df5['Number'], color= 'green')
plt.title('Number of Fatalities v/s Time Period', fontsize=16, fontweight='bold')
plt.xlabel('Time Period', fontsize=12, fontweight='bold')
plt.ylabel('Number of Fatalities', fontsize=12, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Yearwise Trend

# %%
sns.set_style('white')
plt.figure(figsize=(7,5))
plt.plot(df7['Year'],df7['Number'], marker='o', color= 'orange')
plt.title('Yearwise Trend', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=12, fontweight='bold')
plt.ylabel('Number of Fatalities', fontsize=12, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Age Group v/s Number of Fatalities

# %%
sns.set_style('white')
plt.figure(figsize=(7,5))
plt.bar(df8['Age Group'],df8['Number'], color= 'purple')
plt.title('Age Group v/s Number of Fatalities', fontsize=16, fontweight='bold')
plt.xlabel('Age Group', fontsize=12, fontweight='bold')
plt.ylabel('Number of Fatalities', fontsize=12, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Driver Gender v/s Number of Fatalities

# %%
plt.figure(figsize=(7,5))
plt.pie(df9['Number'],labels=df9['Driver Gender'], autopct='%1.1f%%', colors=['green','#F5B727'])
plt.title('Driver Gender v/s Number of Fatalities', fontsize=16, fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# # Driver License Status v/s Number of Fatalities

# %% [markdown]
# ## Driver License Status v/s Number of Fatalities: 0--> Expired,   1--> Valid

# %%
plt.figure(figsize=(7,5))
plt.pie(df11['Number'],labels=df11['Driver License Status'], autopct='%1.1f%%', colors=['#F5279F','#279FF5'])
plt.title('Driver License Status v/s Number of Fatalities', fontsize=16, fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# # Road Type v/s Number of Fatalities

# %%
sns.set_style('white')
plt.figure(figsize=(7,5))
plt.bar(df12['Road Type'], df12['Number'], color= '#73F527')
plt.title('Road Type v/s Number of Fatalities', fontsize=16, fontweight='bold')
plt.xlabel('Road Type', fontsize=12, fontweight='bold')
plt.ylabel('Number of Fatalities', fontsize=12, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Daywise Accident Severity Trend

# %%
sns.set_style('white')
plt.figure(figsize=(7,5))
plt.plot(df13['Day of Week'], df13['Accident Severity'], marker='o', color= 'red')
plt.title('Daywise Accident Severity Trend', fontsize=16, fontweight='bold')
plt.xlabel('Day', fontsize=12, fontweight='bold')
plt.ylabel('Accident Severity', fontsize=12, fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Location v/s Number of Fatalities

# %%
plt.figure(figsize=(7,5))
plt.pie(df14['Number'], autopct='%1.1f%%', colors=['#F56C27','#F5B727','green','#279FF5'])
plt.title('Location v/s Number of Fatalities', fontsize=16, fontweight='bold')
plt.legend(df14['Location'], loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# # Key Findings from Traffic Accident Analysis
#
# ### Temporal Patterns
# ##### Seasonal Impact: October recorded the highest number of fatalities, while July had the lowest
# ##### Annual Trends: 2021 emerged as the year with the most fatalities
# ##### Weekly Patterns: Wednesday showed the highest accident severity rates
# ##### Time of Day: Nighttime accidents resulted in over 2,500 fatalities, significantly exceeding daytime incidents
#
# ### Demographic Insights
# ##### Age Distribution: The 45-59 age group experienced the highest fatality rates, while the 0-17 age group had the lowest
# ##### Gender Patterns: Female drivers were involved in more accidents than male drivers
# ##### Alcohol-Related Incidents: Among drunk driving cases, female drivers had higher accident rates than male drivers
#
# ### Vehicle and Infrastructure Analysis
# ##### Vehicle Type Safety: Cars had the lowest fatality rates compared to other vehicle types
# ##### Road Infrastructure: State Highways accounted for the majority of accidents relative to other road types
#
# ### Geographic Distribution
# ##### Regional Variations: Goa reported the highest number of casualties, while Arunachal Pradesh recorded the lowest

# %% [markdown]
# # Conclusions
#
# ### Immediate Actions Required
# ##### Infrastructure: Upgrade State Highway safety and nighttime lighting
# ##### Enforcement: Increase Wednesday traffic monitoring and night patrol
# ##### Campaigns: Target October safety drives and middle-aged driver education
#
# ### Key Risk Factors Identified
# ##### Time: October months and nighttime hours are most dangerous
# ##### Demographics: Ages 45-59 and female drivers need focused attention
# ##### Location: State Highways and high-traffic states require priority intervention
#
# ### Policy Focus Areas
# ##### Vehicle Safety: Strengthen standards for non-car vehicles
# ##### Alcohol Prevention: Gender-specific drunk driving programs
# ##### Resource Allocation: Redistribute safety resources based on regional casualty data

# %% [markdown]
# # Amisha Jain
# ### B.Tech Computer Science and Engineering
# ### PES University, Bengaluru
# ### Email: jainamisha2004@gmail.com
